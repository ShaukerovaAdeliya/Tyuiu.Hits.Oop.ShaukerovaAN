// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) создайте явную реализации интерфейса и управление зависимостями

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
// Интерфейс для управления отзывами
public interface IReviewable
{
    void DisplayReview();
    void RateProduct(int rating);
    string GetReviewDetails();
}

// Базовый класс Review
public class Review : IReviewable
{
    public int ReviewId { get; set; }
    public string Text { get; set; }
    public int Rating { get; set; }
    public DateTime CreatedDate { get; set; } // Дата создания отзыва
    public string ReviewerName { get; set; } // Имя рецензента

    // Конструктор
    public Review(int reviewId, string text, int rating, string reviewerName)
    {
        ReviewId = reviewId;
        Text = text;
        Rating = rating;
        CreatedDate = DateTime.Now;
        ReviewerName = reviewerName;
    }

    // Явная реализация метода интерфейса DisplayReview
    void IReviewable.DisplayReview()
    {
        Console.WriteLine($"ID отзыва: {ReviewId}, Текст: {Text}, Рейтинг: {Rating}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}");
    }

    // Явная реализация метода интерфейса RateProduct
    void IReviewable.RateProduct(int rating)
    {
        Rating = rating;
        Console.WriteLine($"Рейтинг для отзыва ID {ReviewId} установлен на: {Rating}");
    }

    // Переопределение метода GetReviewDetails
    public virtual string GetReviewDetails()
    {
        return $"ID отзыва: {ReviewId}, Текст: {Text}, Рейтинг: {Rating}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}";
    }
}

// Производный класс ServiceReview
public class ServiceReview : Review
{
    public DateTime VisitDate { get; set; } // Дата посещения

    // Конструктор
    public ServiceReview(int reviewId, string text, int rating, string reviewerName, DateTime visitDate)
        : base(reviewId, text, rating, reviewerName)
    {
        VisitDate = visitDate;
    }

    // Явная реализация метода интерфейса DisplayReview
    public void DisplayReview()
    {
        Console.WriteLine($"ID отзыва: {ReviewId}, Текст: {Text}, Рейтинг: {Rating}, Дата посещения: {VisitDate.ToShortDateString()}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}");
    }
}

// Производный класс ProductReview
public class ProductReview : Review
{
    public int ProductId { get; set; } // Идентификатор продукта

    // Конструктор
    public ProductReview(int reviewId, string text, int rating, string reviewerName, int productId)
        : base(reviewId, text, rating, reviewerName)
    {
        ProductId = productId;
    }

    // Явная реализация метода интерфейса RateProduct
    public void RateProduct(int rating)
    {
        Rating = rating;
        Console.WriteLine($"Рейтинг для продукта ID {ProductId} в отзыве ID {ReviewId} установлен на: {Rating}");
    }

    // Переопределение метода GetReviewDetails
    public override string GetReviewDetails()
    {
        return $"ID отзыва: {ReviewId}, ID продукта: {ProductId}, Текст: {Text}, Рейтинг: {Rating}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}";
    }
}

public class ServiceTimeReview : ServiceReview
{ 
    public TimeSpan StartTime { get; set; }

    public ServiceTimeReview(int reviewId, string text, int rating, string reviewerName, DateTime visitDate, TimeSpan startTime)
        : base(reviewId, text, rating, reviewerName, visitDate)
    {
        StartTime = startTime;
    }

    public override string GetReviewDetails()
    {
        return $"Время посещения: {StartTime}";
    }
}

// Используя интерфейсы для управления отзывами
IReviewable serviceReview = new ServiceReview { ReviewId = 1, Text = "Отличное обслуживание!", Rating = 5, ReviewerName = "Иван", VisitDate = DateTime.Now};
serviceReview.DisplayReview();

IReviewable productReview = new ProductReview(2, "Хороший продукт.", 4, "Мария", 101);
productReview.DisplayReview();

// Изменение рейтингов
serviceReview.RateProduct(5);
productReview.RateProduct(3);

// Получение деталей отзывов
Console.WriteLine(serviceReview.GetReviewDetails());
Console.WriteLine(productReview.GetReviewDetails());
// Out:
// ID отзыва: 1, Текст: Отличное обслуживание!, Рейтинг: 5, Автор: Иван, Дата: 11/22/2024
// ID отзыва: 2, Текст: Хороший продукт., Рейтинг: 4, Автор: Мария, Дата: 11/22/2024
// Рейтинг для отзыва ID 1 установлен на: 5
// Рейтинг для отзыва ID 2 установлен на: 3
// ID отзыва: 1, Текст: Отличное обслуживание!, Рейтинг: 5, Автор: Иван, Дата: 11/22/2024
// ID отзыва: 2, ID продукта: 101, Текст: Хороший продукт., Рейтинг: 3, Автор: Мария, Дата: 11/22/2024

// %%
using System;

// Интерфейс для управления отзывами
public interface IReviewable
{
    void DisplayReview();
    void RateProduct(int rating);
    string GetReviewDetails();
}

// Базовый класс Review
public class Review : IReviewable
{
    public int ReviewId { get; set; }
    public string Text { get; set; }
    public int Rating { get; set; }
    public DateTime CreatedDate { get; set; } // Дата создания отзыва
    public string ReviewerName { get; set; } // Имя рецензента

    // Конструктор
    public Review(int reviewId, string text, int rating, string reviewerName)
    {
        ReviewId = reviewId;
        Text = text;
        Rating = rating;
        CreatedDate = DateTime.Now;
        ReviewerName = reviewerName;
    }

    // Метод для отображения отзыва
    public virtual void DisplayReview()
    {
        Console.WriteLine($"ID отзыва: {ReviewId}, Текст: {Text}, Рейтинг: {Rating}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}");
    }

    // Метод для присвоения рейтинга
    public virtual void RateProduct(int rating)
    {
        Rating = rating;
        Console.WriteLine($"Рейтинг для отзыва ID {ReviewId} установлен на: {Rating}");
    }

    // Метод для получения деталей отзыва
    public virtual string GetReviewDetails()
    {
        return $"ID отзыва: {ReviewId}, Текст: {Text}, Рейтинг: {Rating}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}";
    }
}

// Производный класс ServiceReview
public class ServiceReview : Review
{
    public DateTime VisitDate { get; set; } // Дата посещения

    // Конструктор
    public ServiceReview(int reviewId, string text, int rating, string reviewerName, DateTime visitDate) 
        : base(reviewId, text, rating, reviewerName)
    {
        VisitDate = visitDate;
    }

    // Переопределение метода DisplayReview
    public override void DisplayReview()
    {
        Console.WriteLine($"ID отзыва: {ReviewId}, Текст: {Text}, Рейтинг: {Rating}, Дата посещения: {VisitDate.ToShortDateString()}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}");
    }
}

// Производный класс ProductReview
public class ProductReview : Review
{
    public int ProductId { get; set; } // Идентификатор продукта

    // Конструктор
    public ProductReview(int reviewId, string text, int rating, string reviewerName, int productId) 
        : base(reviewId, text, rating, reviewerName)
    {
        ProductId = productId;
    }

    // Переопределение метода RateProduct
    public override void RateProduct(int rating)
    {
        Rating = rating;
        Console.WriteLine($"Рейтинг для продукта ID {ProductId} в отзыве ID {ReviewId} установлен на: {Rating}");
    }

    // Переопределение метода GetReviewDetails
    public override string GetReviewDetails()
    {
        return $"ID отзыва: {ReviewId}, ID продукта: {ProductId}, Текст: {Text}, Рейтинг: {Rating}, Автор: {ReviewerName}, Дата: {CreatedDate.ToShortDateString()}";
    }
}


// Создание объекта отзыва об услуге
ServiceReview serviceReview = new ServiceReview(1, "Отличное обслуживание!", 5, "Иван", DateTime.Now);
serviceReview.DisplayReview();

// Создание объекта отзыва о продукте
ProductReview productReview = new ProductReview(2, "Хороший продукт.", 4, "Мария", 101);
productReview.DisplayReview();

// Изменение рейтингов
serviceReview.RateProduct(5);
productReview.RateProduct(3);

// Получение деталей отзывов
Console.WriteLine(serviceReview.GetReviewDetails());
Console.WriteLine(productReview.GetReviewDetails());
// Out:
// ID отзыва: 1, Текст: Отличное обслуживание!, Рейтинг: 5, Дата посещения: 11/22/2024, Автор: Иван, Дата: 11/22/2024
// ID отзыва: 2, Текст: Хороший продукт., Рейтинг: 4, Автор: Мария, Дата: 11/22/2024
// Рейтинг для отзыва ID 1 установлен на: 5
// Рейтинг для продукта ID 101 в отзыве ID 2 установлен на: 3
// ID отзыва: 1, Текст: Отличное обслуживание!, Рейтинг: 5, Автор: Иван, Дата: 11/22/2024
// ID отзыва: 2, ID продукта: 101, Текст: Хороший продукт., Рейтинг: 3, Автор: Мария, Дата: 11/22/2024

// %%
// Базовый класс Review
public class Review
{
    public int ReviewId { get; set; } // ID отзыва
    public string Author { get; set; } // Автор отзыва, новый атрибут
    public string Text { get; set; } // Текст отзыва
    public int Rating { get; set; } // Рейтинга отзыва 
    public DateTime DateCreated { get; set; } // Дата создания отзыва, новый атрибут
    
    public Review(int reviewId, string author, string text, int rating, DateTime dateCreated)
    {
        ReviewId = reviewId;
        Author = author;
        Text = text;
        Rating = rating;
        DateCreated = dateCreated; 
    }

    // метод для отображения отзыва
    public virtual void DisplayReview()
    {
        Console.WriteLine($"Отзыв ID: {ReviewId}, Автор: {Author}, Рейтинг: {Rating}\nТекст: {Text}\nДата создания отзыва: {DateCreated}");
    }

    // метод для присвоения рейтинга продукту
    public virtual void RateProduct(int rating)
    {
        Rating = rating; // Присваиваем рейтинг отзыву
    }

    //  метод для получения деталей отзыва.
    public virtual string GetReviewDetails()
    {
        return $"Отзыв ID: {ReviewId}, Рейтинг: {Rating}\nТекст: {Text}";
    }

    // новый метод для редактирования отзыва
    public void EditReview(string newText) 
    {
        Text = newText;
        Console.WriteLine("Отзыв обновлён.");
    }

    // новый метод
    public bool IsPositive()
    {
        return Rating >= 5; // Определяем положительный отзыв
    }
}

// Производный класс ОтзывОбслуживания, простое наследование
public class ServiceReview : Review
{
    public string ServiceName { get; set; } // новый атрибут

    public DateOnly VisitDate { get; set; }

    public ServiceReview(int reviewId, string serviceName, string author, string text, int rating, DateTime dateCreated, DateOnly visitDate)
        : base(reviewId, author, text, rating, dateCreated)
    {
        VisitDate = visitDate;
        ServiceName = serviceName;
    }

    public override void DisplayReview()
    {
        Console.WriteLine($"Отзыв ID: {ReviewId}, Тип товара: {ServiceName}, Автор: {Author}, Рейтинг: {Rating}\nТекст: {Text}\nДата создания отзыва: {DateCreated}");
        Console.WriteLine($"Дата посещения: {VisitDate.ToShortDateString()}");
    }
}

public interface IProductReview
{
    void RateProduct(int rating);
}

// Производный класс ОтзывТовара, (множественное наследование)
public class ProductReview: Review, IProductReview
{
    public string ProductName { get; set; } // новый атрибут

    public int ProductId { get; set; }

    public ProductReview(int reviewId, string productName, string author, string text, int rating, DateTime dateCreated, int productId)
        : base(reviewId, author, text, rating, dateCreated)
    {
        ProductId = productId;
        ProductName = productName;
    }

    public override void RateProduct(int rating)
    {
        base.RateProduct(rating);
        Console.WriteLine($"Продукт с ID {ProductId} был оценён с рейтингом: {Rating}\n");
    }

    public override void DisplayReview()
    {
        Console.WriteLine($"Отзыв ID: {ReviewId}, Тип товара: {ProductName}, Автор: {Author}, Рейтинг: {Rating}\nТекст: {Text}\nДата создания отзыва: {DateCreated}");
    }
}

// Класс ServiceTimeReview наследуется от класса ServiceReview (сложное наследование)
// добавляется дата посещения
public class ServiceTimeReview : ServiceReview
{ 
    public TimeSpan StartTime { get; set; }

    public ServiceTimeReview(int reviewId, string serviceName, string author, string text, int rating, DateTime dateCreated, DateOnly visitDate, TimeSpan startTime)
        : base(reviewId, serviceName, author, text, rating, dateCreated, visitDate)
    {
        StartTime = startTime;
        ServiceName = serviceName;
    }

    public override string GetReviewDetails()
    {
        return $"Время посещения: {StartTime}\n";
    }
}

// Сравнение отзывов
private static void CompareReviews(Review review1, Review review2)
    {
        Console.WriteLine($"Сравнение рейтинга отзывов с ID №{review1.ReviewId} и с ID №{review2.ReviewId}:");
        if (review1.Rating > review2.Rating)
        {
            Console.WriteLine("Отзыв с ID №1 имеет более высокий рейтинг, чем отзыв с ID №3.");
        }
        else if (review1.Rating < review2.Rating)
        {
            Console.WriteLine("Отзыв с ID №3 имеет более высокий рейтинг, чем отзыв с ID №1.");
        }
        else
        {
            Console.WriteLine("Оба отзыва имеют одинаковый рейтинг.");
        }
    }

// первая часть

public interface IService
{
    void Start();
    void Stop();
    int GetSpeed();
}

public interface IOnline : IService
{
    void OnlineReview();
}

public interface IOffline : IService
{
    void OfflineReview();
}

public abstract class Service : IService
{
    public int ID { get; set; }
    public string Name { get; set; }
    protected int Speed;

    public abstract void Start(); 
    public abstract void Stop(); 

    public virtual int GetSpeed()
    {
        return Speed;
    }
}

public class Online : Service, IOnline
{
    public override void Start()
    {
        Speed = 0;
        Console.WriteLine($"ID: {ID}; Название услуги: {Name}. Услугу начали оказывать.");
    }

    public override void Stop()
    {
        Speed = 0;
        Console.WriteLine($"Услугу закончили оказывать.");
    }

    void IOnline.OnlineReview()
    {
        Console.WriteLine("Услугу оказали онлайн.");
    }

    public void Accelerate(int amount)
    {
        Speed += amount;
        Console.WriteLine($"Услуга была оказана за {Speed} суток.");
    }
}

public class Offline : Service, IOffline
{
    public override void Start()
    {
        Speed = 0;
        Console.WriteLine($"ID: {ID}; Название услуги: {Name}. Услугу начали оказывать.");
    }

    public override void Stop()
    {
        Speed = 0;
        Console.WriteLine($"Услугу закончили оказывать.");
    }

    void IOffline.OfflineReview()
    {
        Console.WriteLine("Услугу оказали оффлайн.");
    }

    public void Accelerate(int amount)
    {
        Speed += amount;
        Console.WriteLine($"Услуга была оказана за {Speed} мин.");
    }
}

// вторая часть

public interface IReview
{
    void Start();            // Метод для начала оказания услуги
    void Stop();             // Метод для завершения оказания услуги
    int GetNumber();         // Метод для получения доступа к помещениям
}
//Реализация интерфейса
public class Client : IReview
{
    public void Start()
    {
        Console.WriteLine("Клиент зашел в магазин.");
    }

    public void Stop()
    {
        Console.WriteLine("Клиент вышел из магазина.");
    }

    public int GetNumber()
    {
        return 3; // У клиента есть доступ ко всем помещениям, кроме склада
    }
}

public class Employee : IReview
{
    public void Start()
    {
        Console.WriteLine("Сотрудник зашел в магазин.");
    }

    public void Stop()
    {
        Console.WriteLine("Сотрудник вышел из магазина.");
    }

    public int GetNumber()
    {
        return 4; // У сотрудника есть доступ ко всем помещениям
    }
}

//Создадим класс ReviewInfo, который будет зависеть от интерфейса IReview
public class ReviewInfo
{
    private readonly IReview _review;

    // Внедрение зависимости через конструктор
    public ReviewInfo(IReview review)
    {
        _review = review; 
    }

    public void UseReview()
    {
        _review.Start(); // Входим в магазин
        Console.WriteLine($"У человека есть доступ к {_review.GetNumber()} помещениям.");
        _review.Stop(); // Выходим из магазина
    }
}

ServiceReview serviceReview = new ServiceReview (1, "Клининг", "Мария", "Отличное обслуживание", 10, new DateTime(2024, 06, 05, 20, 30, 0), new DateOnly(2024, 05, 06));
serviceReview.GetReviewDetails(); // получение деталей отзыва
serviceReview.DisplayReview();
Console.WriteLine();

ProductReview productReview = new ProductReview (2, "Ноутбук", "Александр", "Хороший ноутбук, всё устраивает", 10, new DateTime(2024, 12, 28, 10, 30, 0), 505);
productReview.GetReviewDetails(); // получение деталей отзыва
productReview.DisplayReview();
productReview.RateProduct(10);

// Использование новых методов
productReview.EditReview("Прекрасный ноутбук, пользуюсь несколько месяцев, никаких притензий");
Console.WriteLine(productReview.GetReviewDetails());

Console.WriteLine($"Отзыв положительный?: {productReview.IsPositive()}");
Console.WriteLine($"");

ServiceTimeReview serviceTimeReview = new ServiceTimeReview (3, "Ремонт телефона", "Пётр", "Услуга не была оказана", 0, new DateTime(2024, 08, 06, 10, 30, 0), new DateOnly(2023, 08, 05), new TimeSpan(14, 0, 0));
serviceTimeReview.DisplayReview();
Console.WriteLine(serviceTimeReview.GetReviewDetails()); // получение деталей отзыва


CompareReviews(serviceReview, serviceTimeReview); // сравнение
Console.WriteLine();

// первая часть
IOnline myOnline = new Online { ID = 4, Name = "Дизайн интерьера" };
myOnline.Start();
myOnline.OnlineReview();
((Online)myOnline).Accelerate(7);
myOnline.Stop();
Console.WriteLine();
        
IOffline myOffline = new Offline { ID = 5, Name = "Продажа телевизора" };
myOffline.Start();
myOffline.OfflineReview();
((Offline)myOffline).Accelerate(20);
myOffline.Stop();
Console.WriteLine();

// вторая часть

IReview myClient = new Client(); // Создаем объект клиента
ReviewInfo clientInfo = new ReviewInfo(myClient);
clientInfo.UseReview();
Console.WriteLine();

IReview myEmployee = new Employee(); // Создаем объект сотрудника
ReviewInfo employeeInfo = new ReviewInfo(myEmployee); 
employeeInfo.UseReview();
// Out:
// Отзыв ID: 1, Тип товара: Клининг, Автор: Мария, Рейтинг: 10
// Текст: Отличное обслуживание
// Дата создания отзыва: 6/5/2024 8:30:00 PM
// Дата посещения: 5/6/2024
//
// Отзыв ID: 2, Тип товара: Ноутбук, Автор: Александр, Рейтинг: 10
// Текст: Хороший ноутбук, всё устраивает
// Дата создания отзыва: 12/28/2024 10:30:00 AM
// Продукт с ID 505 был оценён с рейтингом: 10
//
// Отзыв обновлён.
// Отзыв ID: 2, Рейтинг: 10
// Текст: Прекрасный ноутбук, пользуюсь несколько месяцев, никаких притензий
// Отзыв положительный?: True
//
// Отзыв ID: 3, Тип товара: Ремонт телефона, Автор: Пётр, Рейтинг: 0
// Текст: Услуга не была оказана
// Дата создания отзыва: 8/6/2024 10:30:00 AM
// Дата посещения: 8/5/2023
// Время посещения: 14:00:00
//
// Сравнение рейтинга отзывов с ID №1 и с ID №3:
// Отзыв с ID №1 имеет более высокий рейтинг, чем отзыв с ID №3.
//
// ID: 4; Название услуги: Дизайн интерьера. Услугу начали оказывать.
// Услугу оказали онлайн.
// Услуга была оказана за 7 суток.
// ...
